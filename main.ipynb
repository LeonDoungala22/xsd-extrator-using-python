# %%
# This code was developed by : Leon Doungala 
# Date: 20 / 03 / 2023 
# Place : Milan

# %%
import Handler
import pandas as pd

# %%
#Extract sese 

Handler.extractor_complexType('sese.023.xsd','sese.023_complexType.csv')
# Out:
# Table saved to : sese.023_complexType.csv
#                                ComplexType Name is complexType type  \
# 0                       ActiveCurrencyAndAmount                 yes
# 1    ActiveOrHistoricCurrencyAnd13DecimalAmount                 yes
# 2             ActiveOrHistoricCurrencyAndAmount                 yes
# 3                      AffirmationStatus8Choice                 yes
# 4                 AlternatePartyIdentification7                 yes
# ..                                          ...                 ...
# 123                      TradeOriginator3Choice                 yes
# 124            TradeTransactionCondition5Choice                 yes
# 125                         TypeOfPrice29Choice                 yes
# 126                   YieldedOrValueType1Choice                 yes
# 127                   YieldedOrValueType2Choice                 yes
#
#                                         extension base attribute name  \
# ...

# %%
#Extract reda

Handler.extractor_complexType('reda.xsd','reda_complexType.csv')
# Out:
# Table saved to : reda_complexType.csv
#                               ComplexType Name is complexType type  \
# 0             ActiveCurrencyAnd13DecimalAmount                 yes
# 1                      ActiveCurrencyAndAmount                 yes
# 2   ActiveOrHistoricCurrencyAnd13DecimalAmount                 yes
# 3                     AmountOrPercentageRange1                 yes
# 4                            Appearance3Choice                 yes
# ..                                         ...                 ...
# 88                        UnitOfMeasure7Choice                 yes
# 89                     UnitOrFaceAmount1Choice                 yes
# 90                                    Warrant4                 yes
# 91                         WarrantStyle3Choice                 yes
# 92                           YieldCalculation6                 yes
#
#                                        extension base attribute name  \
# ...

# %%
Handler.FormatercomplexTtype('sese.023_complexType.csv','[]')
# Out:
# - [] as been correctly handle..
# - sese.023_complexType.csv as been orrectlly update...
#                                ComplexType Name is complexType type  \
# 0                       ActiveCurrencyAndAmount                 yes
# 1    ActiveOrHistoricCurrencyAnd13DecimalAmount                 yes
# 2             ActiveOrHistoricCurrencyAndAmount                 yes
# 3                      AffirmationStatus8Choice                 yes
# 4                 AlternatePartyIdentification7                 yes
# ..                                          ...                 ...
# 123                      TradeOriginator3Choice                 yes
# 124            TradeTransactionCondition5Choice                 yes
# 125                         TypeOfPrice29Choice                 yes
# 126                   YieldedOrValueType1Choice                 yes
# 127                   YieldedOrValueType2Choice                 yes
#
# ...

# %%
Handler.FormatercomplexTtype('reda_complexType.csv','[]')
# Out:
# - [] as been correctly handle..
# - reda_complexType.csv as been orrectlly update...
#                               ComplexType Name is complexType type  \
# 0             ActiveCurrencyAnd13DecimalAmount                 yes
# 1                      ActiveCurrencyAndAmount                 yes
# 2   ActiveOrHistoricCurrencyAnd13DecimalAmount                 yes
# 3                     AmountOrPercentageRange1                 yes
# 4                            Appearance3Choice                 yes
# ..                                         ...                 ...
# 88                        UnitOfMeasure7Choice                 yes
# 89                     UnitOrFaceAmount1Choice                 yes
# 90                                    Warrant4                 yes
# 91                         WarrantStyle3Choice                 yes
# 92                           YieldCalculation6                 yes
#
#                                        extension base attribute name  \
# ...
